# %%
import pandas as pd
log_path = "../data/raw/HDFS_2k.log"

with open(log_path, "r") as f:
    lines = f.readlines()

len(lines)
# Out:
# 2000

# %%
lines[10]
# Out:
# '081109 204722 567 INFO dfs.DataNode$PacketResponder: Received block blk_5402003568334525940 of size 67108864 from /10.251.214.112\n'

# %% [markdown]
# ### Regex for HDFS Logs

# %%
import re

log_pattern = re.compile(
    r'(?P<date>\d{6})\s+'
    r'(?P<time>\d{6})\s+'
    r'(?P<ms>\d+)\s+'
    r'(?P<level>\w+)\s+'
    r'(?P<component>[^:]+):\s+'
    r'(?P<message>.*)'
)

# %% [markdown]
# ### Parse Again (Slowly)

# %%
parsed_logs = []

for line in lines:
    match = log_pattern.match(line)
    if match:
        parsed_logs.append(match.groupdict())

len(parsed_logs)
# Out:
# 2000

# %%
import pandas as pd

df = pd.DataFrame(parsed_logs)
df.head()
# Out:
#      date    time   ms level                     component  \
# 0  081109  203615  148  INFO  dfs.DataNode$PacketResponder
# 1  081109  203807  222  INFO  dfs.DataNode$PacketResponder
# 2  081109  204005   35  INFO              dfs.FSNamesystem
# 3  081109  204015  308  INFO  dfs.DataNode$PacketResponder
# 4  081109  204106  329  INFO  dfs.DataNode$PacketResponder
#
#                                              message
# 0  PacketResponder 1 for block blk_38865049064139...
# 1  PacketResponder 0 for block blk_-6952295868487...
# 2  BLOCK* NameSystem.addStoredBlock: blockMap upd...
# 3  PacketResponder 2 for block blk_82291938032499...
# 4  PacketResponder 2 for block blk_-6670958622368...

# %% [markdown]
# ### Build a Proper Timestamp (One Last Fix)

# %%
df["timestamp"] = pd.to_datetime(
    df["date"] + df["time"],
    format="%y%m%d%H%M%S"
)

df.dtypes
# Out:
# date                 object
# time                 object
# ms                   object
# level                object
# component            object
# message              object
# timestamp    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Observations

# %% [markdown]
# Real-world event data rarely matches initial assumptions.
# Inspecting raw data before parsing is critical.
# Event schemas must be derived, not assumed.
# Once parsed, system logs behave like event-driven analytics data.
# Foundations from earlier days made this dataset manageable.

# %% [markdown]
# ### Sort Events Properly

# %%
df = df.sort_values(by=["component", "timestamp"])
df.head()
# Out:
#        date    time  ms level             component  \
# 28   081109  205931  13  INFO  dfs.DataBlockScanner
# 69   081109  213436  13  INFO  dfs.DataBlockScanner
# 175  081110  002337  13  INFO  dfs.DataBlockScanner
# 196  081110  011237  13  INFO  dfs.DataBlockScanner
# 345  081110  083453  13  INFO  dfs.DataBlockScanner
#
#                                                message           timestamp
# 28   Verification succeeded for blk_-49809165198942... 2008-11-09 20:59:31
# 69   Verification succeeded for blk_-28277162389727... 2008-11-09 21:34:36
# 175  Verification succeeded for blk_-15479543530655... 2008-11-10 00:23:37
# 196  Verification succeeded for blk_699619438987858... 2008-11-10 01:12:37
# 345  Verification succeeded for blk_314136351752080... 2008-11-10 08:34:53

# %% [markdown]
# ### Calculate Time Gaps Between Events

# %%
df["prev_timestamp"] = df.groupby("component")["timestamp"].shift(1)
df["gap_seconds"] = (df["timestamp"] - df["prev_timestamp"]).dt.total_seconds()

# %%
df[["component", "timestamp", "prev_timestamp", "gap_seconds"]].head(10)
# Out:
#                 component           timestamp      prev_timestamp  gap_seconds
# 28   dfs.DataBlockScanner 2008-11-09 20:59:31                 NaT          NaN
# 69   dfs.DataBlockScanner 2008-11-09 21:34:36 2008-11-09 20:59:31       2105.0
# 175  dfs.DataBlockScanner 2008-11-10 00:23:37 2008-11-09 21:34:36      10141.0
# 196  dfs.DataBlockScanner 2008-11-10 01:12:37 2008-11-10 00:23:37       2940.0
# 345  dfs.DataBlockScanner 2008-11-10 08:34:53 2008-11-10 01:12:37      26536.0
# 346  dfs.DataBlockScanner 2008-11-10 08:50:42 2008-11-10 08:34:53        949.0
# 347  dfs.DataBlockScanner 2008-11-10 08:59:33 2008-11-10 08:50:42        531.0
# 357  dfs.DataBlockScanner 2008-11-10 09:36:43 2008-11-10 08:59:33       2230.0
# 568  dfs.DataBlockScanner 2008-11-10 11:21:55 2008-11-10 09:36:43       6312.0
# 645  dfs.DataBlockScanner 2008-11-10 12:17:58 2008-11-10 11:21:55       3363.0

# %% [markdown]
# ### Define Session Breaks

# %%
SESSION_GAP = 300

df["new_session"] = (df["gap_seconds"].isna()) | (df["gap_seconds"] > SESSION_GAP)

# %% [markdown]
# ### Assign Session IDs

# %%
df["session_id"] = df.groupby("component")["new_session"].cumsum()

# %%
df[["component", "timestamp", "gap_seconds", "session_id"]].head(15)
# Out:
#                 component           timestamp  gap_seconds  session_id
# 28   dfs.DataBlockScanner 2008-11-09 20:59:31          NaN           1
# 69   dfs.DataBlockScanner 2008-11-09 21:34:36       2105.0           2
# 175  dfs.DataBlockScanner 2008-11-10 00:23:37      10141.0           3
# 196  dfs.DataBlockScanner 2008-11-10 01:12:37       2940.0           4
# 345  dfs.DataBlockScanner 2008-11-10 08:34:53      26536.0           5
# 346  dfs.DataBlockScanner 2008-11-10 08:50:42        949.0           6
# 347  dfs.DataBlockScanner 2008-11-10 08:59:33        531.0           7
# 357  dfs.DataBlockScanner 2008-11-10 09:36:43       2230.0           8
# 568  dfs.DataBlockScanner 2008-11-10 11:21:55       6312.0           9
# 645  dfs.DataBlockScanner 2008-11-10 12:17:58       3363.0          10
# 698  dfs.DataBlockScanner 2008-11-10 13:56:45       5927.0          11
# 754  dfs.DataBlockScanner 2008-11-10 15:02:54       3969.0          12
# 780  dfs.DataBlockScanner 2008-11-10 15:33:01       1807.0          13
# 789  dfs.DataBlockScanner 2008-11-10 17:36:57       7436.0          14
# 795  dfs.DataBlockScanner 2008-11-10 18:32:00       3303.0          15

# %% [markdown]
# ### Session-Level Metrics

# %%
session_summary = (
    df.groupby(["component", "session_id"])
      .agg(
          session_start=("timestamp", "min"),
          session_end=("timestamp", "max"),
          event_count=("message", "count")
      )
      .reset_index()
)

session_summary["session_duration_sec"] = (
    session_summary["session_end"] - session_summary["session_start"]
).dt.total_seconds()

session_summary.head()
# Out:
#               component  session_id       session_start         session_end  \
# 0  dfs.DataBlockScanner           1 2008-11-09 20:59:31 2008-11-09 20:59:31
# 1  dfs.DataBlockScanner           2 2008-11-09 21:34:36 2008-11-09 21:34:36
# 2  dfs.DataBlockScanner           3 2008-11-10 00:23:37 2008-11-10 00:23:37
# 3  dfs.DataBlockScanner           4 2008-11-10 01:12:37 2008-11-10 01:12:37
# 4  dfs.DataBlockScanner           5 2008-11-10 08:34:53 2008-11-10 08:34:53
#
#    event_count  session_duration_sec
# 0            1                   0.0
# 1            1                   0.0
# 2            1                   0.0
# 3            1                   0.0
# 4            1                   0.0

# %% [markdown]
# ### Event Sequences (Mini Funnel)

# %%
df["event_order"] = df.groupby(["component", "session_id"]).cumcount() + 1

# %%
df[
    (df["component"] == df["component"].iloc[0]) &
    (df["session_id"] == 1)
][["event_order", "level", "message"]]
# Out:
#     event_order level                                            message
# 28            1  INFO  Verification succeeded for blk_-49809165198942...

# %% [markdown]
# ## Day 7 – Key Takeaways

# %% [markdown]
# Sessions convert raw events into meaningful behavior
#
# Time gaps define behavioral boundaries
#
# Components behave like users in product analytics
#
# Sequence analysis reveals system workflows
#
# Interpretation matters more than code

# %% [markdown]
# In SaaS:
# Funnel drop-off = user abandonment
#
# In logs:
# Failure = ERROR level events
#
# Let’s inspect log levels first:

# %%
df["level"].value_counts()
# Out:
# INFO    1920
# WARN      80
# Name: level, dtype: int64

# %% [markdown]
# ### Error Rate per Component

# %%
error_summary = (
    df.groupby("component")
      .agg(
          total_events=("message", "count"),
          error_events=("level", lambda x: (x == "ERROR").sum())
      )
      .reset_index()
)

error_summary["error_rate"] = (
    error_summary["error_events"] / error_summary["total_events"]
)

error_summary.sort_values("error_rate", ascending=False)
# Out:
#                       component  total_events  error_events  error_rate
# 0          dfs.DataBlockScanner            20             0         0.0
# 1                  dfs.DataNode             1             0         0.0
# 2      dfs.DataNode$DataXceiver           454             0         0.0
# 3  dfs.DataNode$PacketResponder           603             0         0.0
# 4                 dfs.FSDataset           263             0         0.0
# 5              dfs.FSNamesystem           659             0         0.0

# %% [markdown]
# ### Error Funnel (Session-Level)

# %%
session_errors = (
    df.groupby(["component", "session_id"])
      .agg(
          total_events=("message", "count"),
          has_error=("level", lambda x: (x == "ERROR").any())
      )
      .reset_index()
)

session_errors["has_error"].value_counts()
# Out:
# False    245
# Name: has_error, dtype: int64

# %%
error_session_rate = session_errors["has_error"].mean()
error_session_rate
# Out:
# 0.0

# %% [markdown]
# ### Do Errors End Sessions?

# %%
session_summary = session_summary.merge(
    session_errors[["component", "session_id", "has_error"]],
    on=["component", "session_id"],
    how="left"
)

session_summary.groupby("has_error")["session_duration_sec"].mean()
# Out:
# has_error
# False    515.261224
# Name: session_duration_sec, dtype: float64

# %% [markdown]
# ### Sequence Before Error

# %%
error_events = df[df["level"] == "ERROR"]

error_events[["component", "timestamp", "message"]].head()
# Out:
# Empty DataFrame
# Columns: [component, timestamp, message]
# Index: []

# %% [markdown]
# #### Now look 3 events before each error (example approach):

# %%
df["is_error"] = df["level"] == "ERROR"

df["prev_event"] = df.groupby(["component", "session_id"])["message"].shift(1)
df["prev2_event"] = df.groupby(["component", "session_id"])["message"].shift(2)

df[df["is_error"]][
    ["component", "prev2_event", "prev_event", "message"]
].head()
# Out:
# Empty DataFrame
# Columns: [component, prev2_event, prev_event, message]
# Index: []

# %% [markdown]
# ### Which Components Produce WARN?

# %%
warn_summary = (
    df.groupby("component")
      .agg(
          total_events=("message", "count"),
          warn_events=("level", lambda x: (x == "WARN").sum())
      )
      .reset_index()
)

warn_summary["warn_rate"] = (
    warn_summary["warn_events"] / warn_summary["total_events"]
)

warn_summary.sort_values("warn_rate", ascending=False)
# Out:
#                       component  total_events  warn_events  warn_rate
# 2      dfs.DataNode$DataXceiver           454           80   0.176211
# 0          dfs.DataBlockScanner            20            0   0.000000
# 1                  dfs.DataNode             1            0   0.000000
# 3  dfs.DataNode$PacketResponder           603            0   0.000000
# 4                 dfs.FSDataset           263            0   0.000000
# 5              dfs.FSNamesystem           659            0   0.000000

# %% [markdown]
# ### Which Components Produce WARN?

# %%
session_warns = (
    df.groupby(["component", "session_id"])
      .agg(has_warn=("level", lambda x: (x == "WARN").any()))
      .reset_index()
)

session_warn_rate = session_warns["has_warn"].mean()
session_warn_rate
# Out:
# 0.1346938775510204

# %% [markdown]
# ### Do WARN Sessions Last Longer?

# %%
session_summary = session_summary.merge(
    session_warns,
    on=["component", "session_id"],
    how="left"
)

session_summary.groupby("has_warn")["session_duration_sec"].mean()
# Out:
# has_warn
# False    548.962264
# True     298.757576
# Name: session_duration_sec, dtype: float64

# %% [markdown]
# ### Plot WARN Events Over Time

# %%
warn_df = df[df["level"] == "WARN"].copy()
warn_df = warn_df.sort_values("timestamp")

# %%
warn_df["timestamp"].min(), warn_df["timestamp"].max()
# Out:
# (Timestamp('2008-11-09 21:40:43'), Timestamp('2008-11-11 01:44:31'))

# %% [markdown]
# ### Are WARNs Clustered?

# %% [markdown]
# #### Calculate time gaps between WARNs:

# %%
warn_df["time_diff_sec"] = warn_df["timestamp"].diff().dt.total_seconds()
warn_df["time_diff_sec"].describe()
# Out:
# count       79.000000
# mean      1278.835443
# std       2914.977923
# min          1.000000
# 25%        109.000000
# 50%        264.000000
# 75%        722.000000
# max      13320.000000
# Name: time_diff_sec, dtype: float64

# %%
(warn_df["time_diff_sec"] < 10).sum()
# Out:
# 4

# %% [markdown]
# ### Bucket Events by Minute

# %%
df["minute_bucket"] = df["timestamp"].dt.floor("T")

warn_per_minute = (
    df[df["level"] == "WARN"]
      .groupby("minute_bucket")
      .size()
)

warn_per_minute.sort_values(ascending=False).head(10)
# Out:
# minute_bucket
# 2008-11-10 08:27:00    3
# 2008-11-09 22:20:00    2
# 2008-11-10 23:19:00    2
# 2008-11-10 12:59:00    2
# 2008-11-09 22:11:00    2
# 2008-11-10 08:10:00    2
# 2008-11-10 13:10:00    1
# 2008-11-10 13:36:00    1
# 2008-11-10 13:25:00    1
# 2008-11-10 13:19:00    1
# dtype: int64

# %% [markdown]
# ### Rolling Instability Rate

# %%
df = df.sort_values("timestamp")

# %%
df["is_warn"] = df["level"] == "WARN"

df["rolling_warn_rate"] = (
    df["is_warn"]
      .rolling(window=50)
      .mean()
)

# %%
df.sort_values("rolling_warn_rate", ascending=False).head(10)
# Out:
#        date    time    ms level                     component  \
# 125  081109  234516  4136  INFO      dfs.DataNode$DataXceiver
# 126  081109  234555  4345  INFO  dfs.DataNode$PacketResponder
# 124  081109  234512  4223  INFO  dfs.DataNode$PacketResponder
# 123  081109  234325  4246  INFO  dfs.DataNode$PacketResponder
# 122  081109  234112  4136  INFO      dfs.DataNode$DataXceiver
# 121  081109  234111  4288  INFO  dfs.DataNode$PacketResponder
# 120  081109  234110    26  INFO              dfs.FSNamesystem
# 119  081109  234107  4261  INFO      dfs.DataNode$DataXceiver
# 118  081109  234027    26  INFO              dfs.FSNamesystem
# 117  081109  233849  4087  INFO  dfs.DataNode$PacketResponder
#
#                                                message           timestamp  \
# 125  Receiving block blk_7654726977769174867 src: /... 2008-11-09 23:45:16
# 126  PacketResponder 1 for block blk_83200881097010... 2008-11-09 23:45:55
# 124  PacketResponder 0 for block blk_-7640601843607... 2008-11-09 23:45:12
# 123  PacketResponder 1 for block blk_-8108913101671... 2008-11-09 23:43:25
# 122  Receiving block blk_-8562334328670278932 src: ... 2008-11-09 23:41:12
# 121  PacketResponder 1 for block blk_20288038501793... 2008-11-09 23:41:11
# 120  BLOCK* NameSystem.allocateBlock: /user/root/so... 2008-11-09 23:41:10
# 119  Receiving block blk_-1259190292740306590 src: ... 2008-11-09 23:41:07
# 118  BLOCK* NameSystem.addStoredBlock: blockMap upd... 2008-11-09 23:40:27
# 117  Received block blk_-3455521536483250153 of siz... 2008-11-09 23:38:49
#
#          prev_timestamp  gap_seconds  new_session  session_id  event_order  \
# 125 2008-11-09 23:41:12        244.0        False          11            8
# 126 2008-11-09 23:45:12         43.0        False           3            5
# 124 2008-11-09 23:43:25        107.0        False           3            4
# 123 2008-11-09 23:41:11        134.0        False           3            3
# 122 2008-11-09 23:41:07          5.0        False          11            7
# 121 2008-11-09 23:38:49        142.0        False           3            2
# 120 2008-11-09 23:40:27         43.0        False           6            2
# 119 2008-11-09 23:38:36        151.0        False          11            6
# 118 2008-11-09 23:28:33        714.0         True           6            1
# 117 2008-11-09 23:31:08        461.0         True           3            1
#
#      is_error                                         prev_event  \
# 125     False  Receiving block blk_-8562334328670278932 src: ...
# 126     False  PacketResponder 0 for block blk_-7640601843607...
# 124     False  PacketResponder 1 for block blk_-8108913101671...
# 123     False  PacketResponder 1 for block blk_20288038501793...
# 122     False  Receiving block blk_-1259190292740306590 src: ...
# 121     False  Received block blk_-3455521536483250153 of siz...
# 120     False  BLOCK* NameSystem.addStoredBlock: blockMap upd...
# 119     False  Receiving block blk_-8788032532930439012 src: ...
# 118     False                                                NaN
# 117     False                                                NaN
#
#                                            prev2_event       minute_bucket  \
# 125  Receiving block blk_-1259190292740306590 src: ... 2008-11-09 23:45:00
# 126  PacketResponder 1 for block blk_-8108913101671... 2008-11-09 23:45:00
# 124  PacketResponder 1 for block blk_20288038501793... 2008-11-09 23:45:00
# 123  Received block blk_-3455521536483250153 of siz... 2008-11-09 23:43:00
# 122  Receiving block blk_-8788032532930439012 src: ... 2008-11-09 23:41:00
# 121                                                NaN 2008-11-09 23:41:00
# 120                                                NaN 2008-11-09 23:41:00
# 119  Receiving block blk_699651392443620263 src: /1... 2008-11-09 23:41:00
# 118                                                NaN 2008-11-09 23:40:00
# 117                                                NaN 2008-11-09 23:38:00
#
#      is_warn  rolling_warn_rate
# 125    False               0.42
# 126    False               0.42
# 124    False               0.42
# 123    False               0.42
# 122    False               0.42
# 121    False               0.42
# 120    False               0.42
# 119    False               0.42
# 118    False               0.42
# 117    False               0.42
